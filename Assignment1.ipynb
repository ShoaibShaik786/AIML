# %%
n = int(input("Enter a number :"))
for i in range(0,n):
  for j in range(0,i+1):
    print("*",end=" ")
  print("\r")
# Out:
# Enter a number :5
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
#Display Table
k = int(input("Enter a number: "))
for i in range(1,11):
  print(k,"x",i,"=",k*i)
# Out:
# Enter a number: 7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70

# %%
#roots of quadratic equation
import cmath
a = int(input("Enter A value : "))
b = int(input("Enter B value : "))
c = int(input("Enter C value : "))
d = (b**2) - ( 4*a*c)
b1 = (-b + cmath.sqrt(d))/(2*a)
b2 = (-b - cmath.sqrt(d))/(2*a)
print(b1,b2)
# Out:
# Enter A value : 1
# Enter B value : 5
# Enter C value : 6
# (-2+0j) (-3+0j)

# %%
#Fibonacci Numbers
def fib(n):
  if n == 1:
    return 0
  elif n == 2:
    return 1
  else:
    return fib(n-1)+fib(n-2)

n = int(input("Enter a number : "))
print(fib(n))
# Out:
# Enter a number : 9
# 21

# %%
#Decimal to Binary
def dec2bin(n):
  if n > 1:
    dec2bin(n//2)
  print(n%2,end="")
n = int(input("Enter a Decimal : "))
dec2bin(n)
# Out:
# Enter a Decimal : 24
# 11000
