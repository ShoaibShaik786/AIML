# %% [markdown]
# ### CSE-221710302060-Shaik Shoaib Aslam

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Reading the given csv file

# %%
pd.set_option('display.max_columns',None)
df = pd.read_csv('https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv')
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  literates_total  \
# 0                 8587                   7283           103319
# ...

# %%
pd.reset_option('display.max_columns')

# %% [markdown]
# ### Question 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name_of_city                    493 non-null    object
#  1   state_code                      493 non-null    int64
#  2   state_name                      493 non-null    object
#  3   dist_code                       493 non-null    int64
#  4   population_total                493 non-null    int64
#  5   population_male                 493 non-null    int64
#  6   population_female               493 non-null    int64
#  7   0-6_population_total            493 non-null    int64
#  8   0-6_population_male             493 non-null    int64
#  9   0-6_population_female           493 non-null    int64
#  10  literates_total                 493 non-null    int64
#  11  literates_male                  493 non-null    int64
# ...

# %%
df.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# ...

# %%
df.dtypes.value_counts()
# Out:
# int64      16
# float64     3
# object      3
# dtype: int64

# %% [markdown]
# ### Question 2

# %%
# For both Series and DataFrame we use sample to generate random columns
# Returns random Columns
df_Col = df.sample(n = 5,axis=1) #  "n" specifies how many random columns to be selected 
df_Col.head()
# Out:
#    male_graduates  population_male  literates_female  state_code  \
# 0            8612            76840             44972           3
# 1            5269            58256             43086          27
# 2            6797            59232             37660          28
# 3           12189            91495             54515          20
# 4            7871            82743             45089          28
#
#    literates_male
# 0           58347
# 1           49347
# 2           46295
# 3           71470
# 4           56203

# %% [markdown]
# ### Question 3

# %%
F2I=df.select_dtypes(include="float64").columns.to_list()
I2F=df.select_dtypes(include="int64").columns.to_list()
df[F2I]=df[F2I].astype('int64')
df[I2F]=df[I2F].astype('float64')
df.dtypes.value_counts()
# Out:
# float64    16
# object      3
# int64       3
# dtype: int64

# %% [markdown]
# ### Question 4

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# #### From the HeatMap we can see there are no missing values

# %% [markdown]
# ### Question 5

# %%
# Checking For Duplicate Data from the dataframe
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name_of_city, state_code, state_name, dist_code, population_total, population_male, population_female, 0-6_population_total, 0-6_population_male, 0-6_population_female, literates_total, literates_male, literates_female, sex_ratio, child_sex_ratio, effective_literacy_rate_total, effective_literacy_rate_male, effective_literacy_rate_female, location, total_graduates, male_graduates, female_graduates]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Question 6

# %%
df[df.population_total == df.population_total.max()]
# Out:
#         name_of_city  state_code   state_name  dist_code  population_total  \
# 185  Greater Mumbai           27  MAHARASHTRA         99          12478447
#
#      population_male  population_female  0-6_population_total  \
# 185          6736815            5741632               1139146
#
#      0-6_population_male  0-6_population_female  ...  literates_female  \
# 185               599007                 540139  ...           4509812
#
#      sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 185        852              902                          90.28
#
#      effective_literacy_rate_male  effective_literacy_rate_female  \
# 185                         93.32                            86.7
#
#             location  total_graduates male_graduates  female_graduates
# 185  19.0760,72.8777          1802371         964964            837407
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Question 7

# %%
plt.figure(figsize = (6,8))
state_pop = df.groupby(df.state_name).mean().population_total

state_pop = pd.DataFrame(state_pop.sort_values(ascending=True))

sns.barplot(x = state_pop.population_total,y = state_pop.index,palette="Blues_d")

# %%
sort_df.sort_values('population_total',ascending = True,inplace = True)
sort_df.head()
# Out:
#     name_of_city  state_code                 state_name  dist_code  \
# 332       Nagda           23             MADHYA PRADESH         18
# 53     Banswara            8                  RAJASTHAN         27
# 211  Hinganghat           27                MAHARASHTRA          8
# 136       Datia           23             MADHYA PRADESH          5
# 376  Port Blair           35  ANDAMAN & NICOBAR ISLANDS          3
#
#      population_total  population_male  population_female  \
# 332            100036            51410              48626
# 53             100128            51240              48888
# 211            100416            51881              48535
# 136            100466            52931              47535
# 376            100608            53247              47361
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 332                 11053                 5840                   5213  ...
# ...

# %% [markdown]
# ### Question 8

# %%
low = df.nsmallest(5,'population_total')
low
# Out:
#     name_of_city  state_code                 state_name  dist_code  \
# 332       Nagda           23             MADHYA PRADESH         18
# 53     Banswara            8                  RAJASTHAN         27
# 211  Hinganghat           27                MAHARASHTRA          8
# 136       Datia           23             MADHYA PRADESH          5
# 376  Port Blair           35  ANDAMAN & NICOBAR ISLANDS          3
#
#      population_total  population_male  population_female  \
# 332            100036            51410              48626
# 53             100128            51240              48888
# 211            100416            51881              48535
# 136            100466            52931              47535
# 376            100608            53247              47361
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 332                 11053                 5840                   5213  ...
# ...

# %% [markdown]
# ### Question 9

# %%
top = df.nlargest(5,'population_total')
top
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 141              Delhi            7    NCT OF DELHI         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 7            Ahmadabad           24         GUJARAT          7
#
#      population_total  population_male  population_female  \
# 185          12478447          6736815            5741632
# 141          11007835          5871362            5136473
# 72            8425970          4401299            4024671
# 184           6809970          3500802            3309168
# 7             5570585          2935869            2634716
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 185               1139146               599007                 540139  ...
# 141               1209275               647938                 561337  ...
# ...

# %% [markdown]
# ### Question 10

# %%
low.sort_values('population_total',ascending = False,inplace = True)
new_df = pd.concat([top,low])
new_df
# Out:
#            name_of_city  state_code                 state_name  dist_code  \
# 185     Greater Mumbai           27                MAHARASHTRA         99
# 141              Delhi            7               NCT OF DELHI         99
# 72            Bengaluru          29                  KARNATAKA         18
# 184  Greater Hyderabad           28             ANDHRA PRADESH         99
# 7            Ahmadabad           24                    GUJARAT          7
# 376         Port Blair           35  ANDAMAN & NICOBAR ISLANDS          3
# 136              Datia           23             MADHYA PRADESH          5
# 211         Hinganghat           27                MAHARASHTRA          8
# 53            Banswara            8                  RAJASTHAN         27
# 332              Nagda           23             MADHYA PRADESH         18
#
#      population_total  population_male  population_female  \
# 185          12478447          6736815            5741632
# ...
