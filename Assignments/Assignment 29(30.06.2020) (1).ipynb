# %% [markdown]
# ### CSE-221710302060-Shaik Shoaib Aslam

# %%
#Importing required libraries 
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/wbcd.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Check the descriptive statistics of the dataset

# %%
df.shape
# Out:
# (569, 32)

# %%
df.isna().sum()# No Null values found
# Out:
# id                   0
# diagnosis            0
# radius_mean          0
# texture_mean         0
# perimeter_mean       0
# area_mean            0
# smoothness_mean      0
# compactness_mean     0
# concavity_mean       0
# points_mean          0
# symmetry_mean        0
# dimension_mean       0
# radius_se            0
# texture_se           0
# perimeter_se         0
# area_se              0
# smoothness_se        0
# compactness_se       0
# concavity_se         0
# points_se            0
# symmetry_se          0
# dimension_se         0
# radius_worst         0
# texture_worst        0
# perimeter_worst      0
# area_worst           0
# smoothness_worst     0
# compactness_worst    0
# concavity_worst      0
# points_worst         0
# symmetry_worst       0
# dimension_worst      0
# dtype: int64

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# count       569.000000        569.000000      569.000000   569.000000
# mean          0.096360          0.104341        0.088799     0.048919
# std           0.014064          0.052813        0.079720     0.038803
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 569 non-null    int64
#  1   diagnosis          569 non-null    object
#  2   radius_mean        569 non-null    float64
#  3   texture_mean       569 non-null    float64
#  4   perimeter_mean     569 non-null    float64
#  5   area_mean          569 non-null    float64
#  6   smoothness_mean    569 non-null    float64
#  7   compactness_mean   569 non-null    float64
#  8   concavity_mean     569 non-null    float64
#  9   points_mean        569 non-null    float64
#  10  symmetry_mean      569 non-null    float64
#  11  dimension_mean     569 non-null    float64
#  12  radius_se          569 non-null    float64
#  13  texture_se         569 non-null    float64
#  14  perimeter_se       569 non-null    float64
# ...

# %%
df.diagnosis.value_counts() # Diagnosis column is the output column
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## Question 2

# %%
sns.barplot(df.perimeter_mean,df.diagnosis)

# %% [markdown]
# #### Observations :
#     For Malignant tumors the perimeter_mean is likely to be high than Benign

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Find the correlation in the data and visualize it

# %%
df.corr()
# Out:
#                          id  radius_mean  texture_mean  perimeter_mean  \
# id                 1.000000     0.074626      0.099770        0.073159
# radius_mean        0.074626     1.000000      0.323782        0.997855
# texture_mean       0.099770     0.323782      1.000000        0.329533
# perimeter_mean     0.073159     0.997855      0.329533        1.000000
# area_mean          0.096893     0.987357      0.321086        0.986507
# smoothness_mean   -0.012968     0.170581     -0.023389        0.207278
# compactness_mean   0.000096     0.506124      0.236702        0.556936
# concavity_mean     0.050080     0.676764      0.302418        0.716136
# points_mean        0.044158     0.822529      0.293464        0.850977
# symmetry_mean     -0.022114     0.147741      0.071401        0.183027
# dimension_mean    -0.052511    -0.311631     -0.076437       -0.261477
# radius_se          0.143048     0.679090      0.275869        0.691765
# ...

# %%
plt.figure(figsize = (22,18))
sns.heatmap(df.corr(),annot = True,fmt = '0.3f')

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Visualize the frequency of the output categories

# %%
sns.countplot(df.diagnosis)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Apply the KNN Algorithm to the dataset without applying scaling operation and try to compare the results before scaling and after scaling.

# %% [markdown]
# #### Without Applying Scaling Operation

# %%
#Splitting data into input and output
X = df.drop(['id','diagnosis'],axis = 1)
y = df.diagnosis

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.30,random_state = 2)

# %%
# Without Scaling the dataset
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=6,metric = 'euclidean')
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=6, p=2,
#                      weights='uniform')

# %%
y_train_pred = knn.predict(X_train)
y_train_pred
# Out:
# array(['B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'M', 'B', 'M', 'M', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M',
#        'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'M',
#        'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'M', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B',
#        'B', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'M',
#        'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'M',
# ...

# %%
# Checking classification report
from sklearn.metrics import classification_report
print(classification_report(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.94      0.98      0.96       257
#            M       0.96      0.89      0.92       141
#
#     accuracy                           0.95       398
#    macro avg       0.95      0.93      0.94       398
# weighted avg       0.95      0.95      0.95       398

# %%
from sklearn.metrics import accuracy_score
score = []
for k in range(1,20):
    knn_model = KNeighborsClassifier(n_neighbors=k)
    knn_model.fit(X_train,y_train)
    pred_test = knn_model.predict(X_test)
    
    score.append(accuracy_score(y_test,pred_test))
print(score)
# Out:
# [0.8947368421052632, 0.8888888888888888, 0.9005847953216374, 0.8947368421052632, 0.9064327485380117, 0.9005847953216374, 0.9181286549707602, 0.8888888888888888, 0.9239766081871345, 0.8888888888888888, 0.9064327485380117, 0.9005847953216374, 0.9181286549707602, 0.9122807017543859, 0.9239766081871345, 0.9064327485380117, 0.9122807017543859, 0.9064327485380117, 0.9122807017543859]

# %%
# Plotting k values and scores
plt.plot(range(1,20),score,'--',marker = 'o',markerfacecolor = 'red')

# %% [markdown]
# #### Observations :
#     Optimum K value is 9

# %%
# Optimum k value is 9
final_model = KNeighborsClassifier(n_neighbors=9,metric = 'euclidean')
final_model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=9, p=2,
#                      weights='uniform')

# %%
# Predicting Train data
final_train_pred = final_model.predict(X_train)

# %%
# Classification report
print(classification_report(y_train,final_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.94      0.98      0.96       257
#            M       0.95      0.88      0.92       141
#
#     accuracy                           0.94       398
#    macro avg       0.95      0.93      0.94       398
# weighted avg       0.94      0.94      0.94       398

# %%
# Prediction on test data
final_test_pred = final_model.predict(X_test)

# %%
# Classification report
print(classification_report(y_test,final_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.91      0.97      0.94       100
#            M       0.95      0.86      0.90        71
#
#     accuracy                           0.92       171
#    macro avg       0.93      0.91      0.92       171
# weighted avg       0.93      0.92      0.92       171

# %% [markdown]
# #### With Scaling Operation

# %%
# Preparing training and testing data
from sklearn.model_selection import train_test_split
X1_train,X1_test,y1_train,y1_test = train_test_split(X,y,test_size = 0.30,random_state = 2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Scaling for train data
scaled_X1_train = pd.DataFrame(scaler.fit_transform(X1_train),columns = X1_train.columns)
# Scaling for test data
scaled_X1_test = pd.DataFrame(scaler.transform(X1_test),columns = X1_test.columns)

# %%
## Fitting scaled model on knn and generating list of accuracy scores 
# Cheking for optimum k-value
from sklearn.metrics import accuracy_score
scores = []
for k in range(1,20):
    knn_model1 = KNeighborsClassifier(n_neighbors=k)
    knn_model1.fit(scaled_X1_train,y1_train)
    pred_test1 = knn_model1.predict(scaled_X1_test)
    scores.append(accuracy_score(y1_test,pred_test1))
scores
# Out:
# [0.9181286549707602,
#  0.9473684210526315,
#  0.9590643274853801,
#  0.9415204678362573,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9649122807017544,
#  0.9532163742690059,
#  0.9590643274853801,
#  0.9532163742690059,
#  0.9532163742690059,
#  0.9415204678362573,
#  0.9473684210526315,
#  0.935672514619883,
#  0.9473684210526315,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9473684210526315]

# %% [markdown]
# #### Observations:
#     We can see accuracy scores are much efficient with scaled data,than unscaled data

# %%
# Plotting k values and scores
plt.plot(range(1,20),scores,'--',marker = 'o',markerfacecolor = 'red')

# %% [markdown]
# #### Observations :
#     Optimum k Value is 7

# %%
# Optimum k value is 7
final_model1 = KNeighborsClassifier(n_neighbors=7,metric = 'euclidean')
final_model1.fit(scaled_X1_train,y1_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
final_train_pred1 = final_model1.predict(scaled_X1_train)

# %%
#Classification report
print(classification_report(y1_train,final_train_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.97      1.00      0.99       257
#            M       1.00      0.95      0.97       141
#
#     accuracy                           0.98       398
#    macro avg       0.99      0.98      0.98       398
# weighted avg       0.98      0.98      0.98       398

# %%
# Prediction on test data
final_test_pred1 = final_model1.predict(scaled_X1_test)
# Classification report
print(classification_report(y1_test,final_test_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.95      0.99      0.97       100
#            M       0.99      0.93      0.96        71
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.96      0.96       171
# weighted avg       0.97      0.96      0.96       171

# %% [markdown]
# #### Observations :
#     In Recall, Precision, f1-score , accuracy the scaled data has more efficient predictions than with normal data.
