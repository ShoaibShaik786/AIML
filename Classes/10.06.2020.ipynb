# %% [markdown]
# ### CSE-221710302060-Shaik Shoaib Aslam

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill'].hist()

# %%
plt.hist(tips['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
tips['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
(tips['total_bill'] >= 3.07) & (tips['total_bill'] >= 7.844)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: total_bill, Length: 244, dtype: bool

# %% [markdown]
# ### Distribution plot

# %%
sns.distplot(tips['total_bill'],kde = False)

# %% [markdown]
# ### Relative Plot

# %%
sns.relplot('total_bill','tip',data=tips)

# %%
sns.relplot('total_bill','tip',data=tips,hue='smoker')

# %%
sns.relplot('total_bill','tip',data=tips,hue='smoker',col='sex')

# %%
sns.relplot('total_bill','tip',data=tips,hue='smoker',style = 'smoker')

# %%
sns.__version__
# Out:
# '0.10.0'

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
sns.relplot('total_bill','tip',data=tips,kind='scatter')

# %%
sns.relplot('total_bill','tip',data=tips,kind='line')

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot('total_bill','tip',data=tips)

# %% [markdown]
# ### Categorical Plot

# %%
sns.catplot('day','tip',data=tips,hue='smoker')

# %% [markdown]
# ### Swarm Plot

# %%
sns.catplot('day','tip',data=tips,kind = "swarm")

# %%
sns.catplot('day','tip',data=tips,hue='smoker',kind = "swarm")

# %%
sns.catplot('day','tip',data=tips,hue='smoker',kind = "swarm",col='sex')

# %%
sns.catplot('sex','tip',data=tips,hue='smoker',kind = "swarm")

# %%
sns.catplot('time','tip',data=tips,hue='smoker',kind = "swarm")

# %%
sns.catplot('day','tip',data=tips,hue='smoker',kind = "strip")

# %% [markdown]
# ### Box Plot

# %%
sns.catplot('day','total_bill',data=tips,kind = "box")

# %%
sns.catplot('day','total_bill',data=tips,kind = "box",hue = 'sex')

# %% [markdown]
# ### Count Plot

# %%
sns.catplot('day',data=tips,kind = "count")

# %%
sns.catplot('day',data=tips,hue='smoker',kind = "count")

# %%
sns.catplot('day',data=tips,hue='smoker',kind = "count",hue_order = ['No','Yes'])

# %%
sns.boxplot(tips['tip'])

# %%
sns.boxplot(y = tips['tip'])

# %% [markdown]
# ### Violin Plot

# %%
sns.catplot('day','tip',data=tips,hue='smoker',kind = "violin")

# %% [markdown]
# ### Boxen Plot

# %%
sns.catplot('day','tip',data=tips,hue='smoker',kind = "boxen")

# %% [markdown]
# ### Point Plot

# %%
sns.catplot('day','tip',data=tips,hue='smoker',kind = "point")

# %%
sns.catplot('day','tip',data=tips,kind = "bar")

# %%
sns.distplot([tips['tip']])

# %%
sns.distplot([tips['tip']],kde = False)

# %%
sns.distplot([tips['tip']],hist = False)

# %%
sns.distplot([tips['tip']],rug = True)

# %%
sns.jointplot('total_bill','tip',data = tips)

# %%
sns.jointplot('total_bill','tip',data = tips,kind='kde')

# %%
tips.dtypes!='category'
# Out:
# total_bill     True
# tip            True
# sex           False
# smoker        False
# day           False
# time          False
# size           True
# dtype: bool

# %%
num_col = tips.columns[tips.dtypes!='category']

# %%
for i in range(len(num_col)):
    for j in range(len(num_col)):
        print(num_col[i],num_col[j])
# Out:
# total_bill total_bill
# total_bill tip
# total_bill size
# tip total_bill
# tip tip
# tip size
# size total_bill
# size tip
# size size

# %%
val = 1
for i in range(len(num_col)):
    for j in range(len(num_col)):
        plt.subplot(3,3,val)
        plt.scatter(tips[num_col[i]],tips[num_col[j]])
        plt.title(num_col[i]+' '+num_col[j])
        val += 1

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue = "smoker")

# %%
sns.pairplot(tips,hue = 'sex')

# %%
sns.pairplot(tips,hue = 'sex',kind = 'reg')

# %% [markdown]
# ### Regression Plot

# %%
sns.set(style = "whitegrid")
sns.regplot('tip','total_bill',data = tips)

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
